# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing, load_iris
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import train_test_split
from sklearn.neighbors import (
    KNeighborsClassifier, KNeighborsRegressor, 
    RadiusNeighborsClassifier, RadiusNeighborsRegressor
)
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (150, 4)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y.shape
# Out:
# (150,)

# %%
# split_train_test (8:2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %%
# declare and fit knn classifier with n_neighbors=100, metric=euclidean, weights=distance
knn_clf = KNeighborsClassifier(n_neighbors=100, metric="euclidean", weights="distance")
knn_clf.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=100, weights='distance')

# %%
# predict for training and test set.

# %%
y_train_pred = knn_clf.predict(x_train)
y_train_prob = knn_clf.predict_proba(x_train)

# %%
y_test_pred = knn_clf.predict(x_test)
y_test_prob = knn_clf.predict_proba(x_test)

# %%
knn_clf.score(x_train, y_train)
# Out:
# 1.0

# %%
knn_clf.score(x_test, y_test)
# Out:
# 0.8666666666666667

# %%
# to see neighbors

# %%
nn_train = knn_clf.kneighbors(x_train)

# %%
nn_test = knn_clf.kneighbors(x_test)

# %%
nn_test_distances, nn_test_indexes = nn_test

# %%
nn_test_distances
# Out:
# array([[0.14142136, 0.26457513, 0.34641016, ..., 2.78926514, 2.82311884,
#         2.83196045],
#        [0.33166248, 0.34641016, 0.37416574, ..., 3.04138127, 3.04138127,
#         3.07083051],
#        [0.24494897, 0.24494897, 0.31622777, ..., 3.64965752, 3.67151195,
#         3.67287353],
#        ...,
#        [0.26457513, 0.42426407, 0.45825757, ..., 3.66742416, 3.69052842,
#         3.69459064],
#        [0.36055513, 0.36055513, 0.41231056, ..., 3.93700394, 3.93700394,
#         3.94588393],
#        [0.17320508, 0.17320508, 0.24494897, ..., 4.88364618, 4.9010203 ,
#         4.92036584]])

# %%
nn_test_distances.shape
# Out:
# (30, 100)

# %%
nn_test_indexes
# Out:
# array([[ 86,  91,  43, ...,  69,  90,  79],
#        [ 30,  81,  67, ...,  16,  96,  68],
#        [ 76,  48,  93, ..., 106,  35,  34],
#        ...,
#        [108,   1,  93, ...,  54,  96, 106],
#        [  9,  80, 110, ...,  98, 106,   7],
#        [ 84,  16, 106, ...,  40,  45,  83]])

# %%
nn_test_indexes.shape
# Out:
# (30, 100)

# %%
# how to get neighbors manually
# 1. calculate distances with all training samples
# 2. find the k-samples with smallest distances

# %%
dist_mat = pairwise_distances(x_test, x_train)

# %%
dist_mat.shape
# Out:
# (30, 120)

# %%
np.argsort(dist_mat[0, :])
# Out:
# array([ 86,  91,  43,  27,  38,  81,  67,  95, 119,  63, 100,   3,  89,
#         28,  71,  78,  64,  14,  75,  66,  10, 117,  30,  97,  36,  20,
#        115,  74,   4,  72,   1,  77,  76,  48, 108,  21, 113,  50,  51,
#         25,   9,  42,  59,  80, 110,  93,  13,  57, 104,  23,  19, 107,
#         33,  46,   8,  44,   6,  12,   5,  15,  22, 102,  47,  73,  40,
#         94,  11, 103,  34,  17,  32,   0,  82,   7,  52,  49,  45, 101,
#         99,  92, 106,  54, 111,  53,  68,  16,  98,  65,  83,  18,  61,
#         39,  96,  87,  58,  26,  84,  69,  90,  79,  60,   2,  31,  62,
#         88,  85,  35,  29,  37, 114,  55, 112, 105,  56, 109,  41, 118,
#        116,  70,  24])

# %%
np.argsort(dist_mat[0, :])[:3]
# Out:
# array([86, 91, 43])

# %%
# declare and fit radius neighbor (with radius=0.9, metric=manhattan, weights=uniform)
rnn_clf = RadiusNeighborsClassifier(radius=0.9, metric="manhattan", weights="uniform")
rnn_clf.fit(x_train, y_train)
# Out:
# RadiusNeighborsClassifier(metric='manhattan', radius=0.9)

# %%
y_train_pred_rnn = rnn_clf.predict(x_train)
y_train_prob_rnn = rnn_clf.predict_proba(x_train)

# %%
y_test_pred_rnn = rnn_clf.predict(x_test)
y_test_prob_rnn = rnn_clf.predict_proba(x_test)
# Out:
# /Users/taekholee/miniconda3/envs/dmclass/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:819: UserWarning: Outlier label -1 is not in training classes. All class probabilities of outliers will be assigned with 0.
#   warnings.warn(
# /Users/taekholee/miniconda3/envs/dmclass/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:819: UserWarning: Outlier label -1 is not in training classes. All class probabilities of outliers will be assigned with 0.
#   warnings.warn(

# %%
nn_train_distances_rnn, nn_train_indexes_rnn = rnn_clf.radius_neighbors(x_train)

# %%
nn_test_distances_rnn, nn_test_indexes_rnn = rnn_clf.radius_neighbors(x_test)

# %%
nn_test_indexes_rnn
# Out:
# array([array([43, 27, 86, 91, 38]),
#        array([ 27, 117,  81,  95,  14,   4,  67,  66,  64,  30,   3,  28,  10,
#               115,   1,  72])                                                 ,
#        array([ 76,   4,  30, 113, 115, 108,   1,  48,  72,  93,  77,  13]),
#        array([ 32,  57, 102,  73,  33,  46,  44,  12]),
#        array([89, 75, 71]), array([88, 83, 31]),
#        array([  0,   2, 106,  98,  96,  92,  15,  16,  84,  68,  62,  54,  52,
#                47])                                                           ,
#        array([  0, 106,   5,   6,   7, 103, 101,  98,  11,  96,  15,  16,  84,
#                82,  22,  69,  68,  26,  61,  54,  53,  34])                   ,
#        array([106,   6, 103, 101,  98,  11,  96,  92,  15,  16,  84,  22,  68,
#                62,  54,  52,  47])                                            ,
#        array([], dtype=int64),
#        array([111, 106,   7, 101,  90,  16,  84,  82,  22,  69,  68,  26,  61,
#                53,  34,  39])                                                 ,
#        array([  0,   2, 106,   6, 103,  98,  11,  96,  92,  16,  84,  68,  62,
#                54,  47])                                                      ,
#        array([117, 115, 108,   1,  51]),
#        array([111,   7, 101,  90,  82,  69,  68,  26,  61,  29,  55,  53,  34,
#                39])                                                           ,
#        array([  0, 111, 106,   5,   6,   7, 103, 101,  98,  11,  96,  15,  16,
#                84,  82,  22,  69,  68,  26,  61,  54,  53,  34])              ,
#        array([111, 106,   5,   7, 101,  11,  90,  16,  84,  82,  69,  68,  26,
#                61,  55,  53,  34,  39])                                       ,
#        array([114,   2,  98,  92,  62,  35]),
#        array([  0, 114,   2, 106,  98,  15,  16,  84,  69,  68,  54]),
#        array([74]),
#        array([  0, 106,   6,   7, 101,  98,  11,  96,  15,  16,  84,  82,  22,
#                69,  68,  26,  62,  61,  54])                                  ,
#        array([51, 21,  9, 59, 42, 80]),
#        array([115,   1,  77,  51,  21,   9,  59,  42]),
#        array([111, 106,   7, 101,  11,  90,  16,  84,  82,  22,  69,  68,  26,
#                61,  54,  53,  34])                                            ,
#        array([115,  77,  21,   9,  59,  42, 110,  80,  19]),
#        array([  1,  77,  51,  21,   9,  59,  57,  42, 110,  80]),
#        array([106,   7, 103, 101,  98,  11,  96,  16,  84,  69,  68,  26,  62,
#                61,  55,  54,  53])                                            ,
#        array([111, 106,   7, 101,  11,  90,  16,  84,  82,  22,  69,  68,  26,
#                61,  54,  53,  34,  39])                                       ,
#        array([108,   1,  93,  77,  51,  21]),
#        array([ 48,  74,  21,   9, 110,  80]),
#        array([106,   7, 103, 101,  98,  11,  96,  16,  84,  82,  22,  69,  68,
#                26,  62,  61,  55,  54])                                       ],
#       dtype=object)

# %%
# load housing dataset

# %%
housing = fetch_california_housing()

# %%
x = housing.data
y = housing.target

# %%
# randomly select 1000 samples (only in class, for fast practice)

# %%
n_sample = x.shape[0]

# %%
sample_indexes = np.random.choice(n_sample, 1000)
sample_indexes.shape
# Out:
# (1000,)

# %%
sample_indexes
# Out:
# array([13076,  7124, 10045,  1408,  6177, 18821,  7314, 14333,  5076,
#        13475,  2526,  3920, 13098,  7712,  1721,  2229,  2076, 16848,
#        14488,  1661, 14237, 19155, 13096,  7580, 12522, 10061,  2508,
#        15118,  7204, 14633, 12684,  9499,  7970, 20118, 13907, 12836,
#         1714, 14446, 20310, 11482, 11676, 12727,  4190, 19396, 17165,
#        16214, 12838,  2112,  9965, 15387, 14288, 15976, 13333,  6472,
#         4249,  6231, 12534, 10527, 10814, 13718,   941,  7814, 14615,
#         1123,  1855, 19584, 16112,  6157, 11522,  6133, 13278,  8915,
#          526, 15157,  4005,  4549,  1092, 19363,  1281,  7643, 11270,
#        13376, 15290,  9948, 13990,  7797,  5337, 12782,  9338, 14181,
#        15546, 15905, 10108, 15891, 14695, 15255, 11064, 18429, 17816,
#        11278,  1183,  2436,  8876, 14583, 18644, 16649, 13202, 14359,
#         2223, 13091,   690,  2316, 10236,  1623,  2867,    55,  8112,
#        17575, 18884, 10420, 19477, 20304, 11998,  6517,  4125,  1099,
#        10186,  9637,  8353, 12422,  8705, 11451,  7608, 19148, 18164,
#        14461, 13472, 16864, 15175, 16691,  7923, 12935, 15691,  1375,
#        11832, 15392, 20452, 19133, 19535, 11991, 17009,  1773,  8618,
#        13979,  7690,  9563,  6841, 10459,  1726,   694,  7006, 16615,
#        14973,  8780, 16291, 18600, 19766,   619, 17333,  5041, 12917,
#        16730, 16170,  8434, 19916,  6273, 10757, 13118, 10985,  7983,
#        12498,  1992, 18897,  8221,  9189,  2012, 16410,  9500, 10578,
#        19472,  4377,  6186, 16225, 16905, 17539,  9531,  3644,  8475,
#         4468,  7172, 15603,   535, 12554, 10276, 17432,  2263, 17824,
#         3359, 15403,  9083, 19714,  2038, 12950, 11815,  6589, 18448,
#         2468,  4100,  6474,  9939,  1903,  7133, 16147,  7022, 15695,
#        19810,  1712, 10998, 10797, 11038, 15470, 17512,  7682,  7324,
#        15217,   900, 11449, 12405, 15274, 12194,   381,  8499, 19099,
#         4781,  8537,  4049,  6844, 15710,  6795,  3256, 10407, 18627,
#         1966, 10078,   742, 12668,  7686, 16461,   936,  4845,  3190,
#        13591, 15709, 15601, 14086, 10711,  4821, 15695,  6271, 19589,
#        12143, 19837, 17540, 20268, 13138,  2737, 19266, 17040, 14447,
#        19662, 11056,  2589, 20638, 10835,  4973, 14506, 11684,  9730,
#        18165, 10377,  9774,  7008,  7938,  7593,  4551, 15392,   872,
#         6102,  9427, 12018,  6990, 12067, 11012,  8734, 19490,  9622,
#        10644,  7280,  8025,  7362, 20167,  5141,  4263,  7709,  4748,
#         6025,   144,  6756, 15963, 18763, 17906,  9268, 11786, 17666,
#          752, 10154, 20528, 17823, 20233,  5952,  8892,  1937, 11831,
#         3147, 18476, 11706,  1850, 13860, 10724, 16511,  2734,  6143,
#         1098,   735, 15138, 11056,   443,   118, 16105, 14301,  5746,
#        19445, 10686,  6893, 12047, 15073,  4573,  7406, 16251,  3030,
#         3988,  9481,  3693,  7979,  7010,  7671, 16281, 14553, 10962,
#        14277,  4119, 14305, 13679, 12711, 10734, 16854,  5987,   539,
#        15779, 15957,  9080,  6498,  6949, 12465, 18918, 18139,  3823,
#          620,  5310, 17517, 18578,  2599,  7384,  5575,  5430, 14953,
#        20026, 12436, 10337, 18132,  7841,  7436, 16275, 11161,  1550,
#         5319,  4654, 13595,  9466,  4898, 10708,  7882,  3408,  7436,
#         7437, 18981,  1353,  7994, 19301,  8298,  3262, 17948,  8634,
#         6157,  1514,   489, 18652, 10952, 14409, 14832, 18873,  7362,
#          692,  3224, 20344,  1762,  2513,  7160,  3889, 16584, 17485,
#         8709, 14400, 19718, 15254, 19195,  2013,  6145,   746,   240,
#        10045, 17848, 20370, 19952, 20508, 12133, 10745, 18338, 14801,
#         8327, 14972, 15153, 12097,  2327,  1920,  5590,  1313, 13611,
#         4005,   617,  1896,  3004,  1022,   402, 14733,  7427,  9097,
#        13732,   562, 10853,  5661,   312, 14849,  9319,   435,  4593,
#         8244,   762, 10017,  3351,   324, 14925,  5131,  9676,  9123,
#        15009,  3331,  1131, 14727, 17796, 19044, 17020, 20388,  5938,
#        10181, 20307, 20327, 12102,  8434, 11518, 10769,  5876,  8633,
#        19045, 18137,  2486, 11617, 16994,  8218, 12884, 15277, 18359,
#         2276,   860, 13359,   868, 13074, 17806, 17508, 18709, 13029,
#        15366,  4642, 18704,  4368,  4561,  8641,  8851, 10039, 15397,
#         4546, 19147,  9787,  6927,  6351,   935,  1375, 15389,  3864,
#        10659, 17659, 18764,  1315,  3145,  2140,  8635, 19000,  5764,
#        10403,  4104, 13676, 18668,  7371, 16772,  4438, 17217, 18752,
#        12529, 11129, 12492, 12297,  8519, 10796,  2641,  6342,  8476,
#        16862, 18262, 16653,  5677,  9210,  6531,   302, 15594, 16289,
#        15211, 19571, 16303, 10287,   290, 12521, 16243, 15158,   557,
#        20247, 13270,  6174, 19576,  1594,  9172, 14490, 13827, 13584,
#        14990,  5097, 10392, 14028,  5909, 11036, 14176,  8375,  7404,
#          847,  2889, 15783,  3797,  9576,  6936,  9164, 16402,  1388,
#         4007,   270, 17556, 14941, 18841,  5278,  4019,  3195,  6327,
#         9449,  9822,  1871, 11323, 11509, 11063, 19442, 16887, 12489,
#        11904, 19896, 18129, 10343, 15368,  8489,   779, 12312, 18935,
#         1783,  5768, 10949, 13565, 14387,  2269, 15700, 14400, 16149,
#        16271, 15862,  2926,  8881,  1178, 19079,  2676,  9337,  8734,
#        17472,  1166,  9340, 14891,  5074, 15093,  2045, 16841,  4870,
#         9261, 10281, 18730,  9580,  8417, 10694, 14713, 12784, 15783,
#         7853,  2652,  2659, 12184,  1567,  2145,   911, 11308,  2793,
#         4066,  6329, 16255, 15888,  7377,  8926, 16226, 10018, 12074,
#         1584,  3710,  7957,   716,  4354,  6381, 17871, 13028, 14345,
#        19634,  4232, 12016, 11399,   441,  1704,  5961,  3384,  5363,
#        13507, 13519,  1888, 16154, 15620, 12594,  4613, 17841, 13856,
#        20470, 14611,   615, 20029,  2752, 19382,  5082, 14520,  7342,
#        14052,  8688,   513,  9924,  7967,  4241,  1346, 20546,    46,
#        12499, 17628, 12858,  4689,  9617, 14980, 10487, 15321,  9013,
#         6685,    61,  7316, 17866,  5539, 14257, 16164, 13029,  8972,
#         1490, 12518, 15138,  8232,  1714,   901,  1339,  7875, 12477,
#        11443, 18897, 18956, 16715, 19793,  9283,  1729,   586, 10564,
#        13977, 14529, 19677, 18020,  4989,  6876,  3473, 18495,  7680,
#        16566, 16128,  3193, 13049,  5822,  6966, 10237, 10920,  8703,
#         8999, 12164, 11636, 12848, 18790,  1148,  3573, 11784,  2707,
#         4258,  3396, 12724, 18462,  5142, 10415, 14322, 16935,  1598,
#         4379, 14631, 10127,  6282,   284,  8487, 12024,  5348,  9540,
#        19505,  7832,  6771,  2739,  7896, 18047, 20489,  7971,  2051,
#         7280, 12803, 18308, 19877,  2055, 14016,  1877, 10110,   297,
#        10636, 12713, 11325,  2417, 11683,  7869,  3165, 15796,  7245,
#        17516, 20229, 13739,  1061, 16497, 11902, 18405,  2774,  4994,
#        19720, 13207, 10058,  5105,  8262,  9252,  6971, 12763,  1218,
#         9936, 18963, 20592, 13633, 16815, 19726, 18089,  7462, 19729,
#        14689, 11005,  4744,  2926,  1043, 10565, 13152, 14841,  1095,
#        12029, 15054, 13594, 14387,  1888, 14073,    78,  9504, 20431,
#         2609,  9420, 12812,  8731, 20295,  9816,  6128, 18619, 16306,
#        11658, 16156, 14220,  5216,  3982,  9619,  8662, 18609, 13421,
#         8681, 11938,  7898, 19650,  9194, 16815, 14787,  8144, 15798,
#         9948, 12842,  3108, 12617,  2148, 11414, 17957,  2364, 11688,
#        12373,  1717, 19882,  1739, 17489,  7956,  3546, 12512, 15098,
#        12425,  4273,  3839,  2850, 14406, 19699, 19528,  4721, 18282,
#         4579, 18396,  8609,   565,  1202,  1613, 12994, 17547,  2170,
#          921, 16309,  5052, 16798, 16926, 15362, 20310, 17287,   621,
#        10141,  4537, 16472,  2083, 16045, 10227,  6137, 10209, 16910,
#         9457,  9932,  9036,   528, 18724, 20550,  2911,  8110, 14769,
#        11704,  3992,  4328,  7325, 13388, 17557,  4482,  4544,  5368,
#        13504])

# %%
x = x[sample_indexes]
y = y[sample_indexes]

# %%
x.shape
# Out:
# (1000, 8)

# %%
y.shape
# Out:
# (1000,)

# %%
# split train test set (8:2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape
# Out:
# (800, 8)

# %%
x_test.shape
# Out:
# (200, 8)

# %%
y_train.shape
# Out:
# (800,)

# %%
y_test.shape
# Out:
# (200,)

# %%
# declare and fit k nearest neighbor regressor (n_neighbors=10, metric=euclidean, weights=uniform)

# %%
knn_reg = KNeighborsRegressor(n_neighbors=10, metric="euclidean", weights="uniform")
knn_reg.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(metric='euclidean', n_neighbors=10)

# %%
y_train_pred = knn_reg.predict(x_train)
y_test_pred = knn_reg.predict(x_test)

# %%
nn_dist_train, nn_idx_train = knn_reg.kneighbors(x_train)

# %%
nn_dist_test, nn_idx_test = knn_reg.kneighbors(x_test)

# %%
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
np.mean(x_train_scaled, axis=0)
# Out:
# array([ 2.90878432e-16,  7.55645546e-17, -1.25906230e-15,  2.83788618e-15,
#        -8.52096171e-17, -7.32469640e-16, -6.56905086e-15, -7.72382158e-15])

# %%
np.std(x_train_scaled, axis=0)
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1.])

# %%
np.mean(x_test_scaled, axis=0)
# Out:
# array([ 0.05432788, -0.05951009,  0.10388935,  0.06266112,  0.0963757 ,
#         0.61294295,  0.0081619 ,  0.01930721])

# %%
np.std(x_test_scaled, axis=0)
# Out:
# array([1.07208641, 0.98960742, 1.85372475, 2.20160899, 1.28631757,
#        7.36927594, 1.02441622, 1.03173272])

# %%
knn_reg.fit(x_train_scaled, y_train)
# Out:
# KNeighborsRegressor(metric='euclidean', n_neighbors=10)

# %%
nn_dist_test_scaled, nn_idx_test_scaled = knn_reg.kneighbors(x_test_scaled)
